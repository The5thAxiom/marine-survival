# %% [markdown]
# # Dataset Creation

# %%
import os
from math import log10
import random
import json
import cv2

# %% [markdown]
# ## Defining the Functions Needed

# %%
def left_pad_number(number: int, target_len: int=6):
    if number == 0:
        return '0' * 6
    elif number > 999999:
        return str(number)
    else:
        return '0' * (target_len - int(log10(number)) - 1) + str(number)

def get_file_name_without_extension(file_path: str):
    return ''.join(file_path.split('/')[-1].split('.')[:-1])

# %%
name = get_file_name_without_extension('datasets/MOBDrone/videos/DJI_0804_0001_30m_1.mp4')
print(name)
print(f'{name}_{left_pad_number(21)}.PNG')
# Out:
# DJI_0804_0001_30m_1
# DJI_0804_0001_30m_1_000021.PNG

# %%
def split_video_into_images(video_path, frames_to_take: int=-1):
    # DJI_0804_0001_30m_1_000004.PNG
    video_name = get_file_name_without_extension(video_path)
    video = cv2.VideoCapture(video_path)
    num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_indexes = None
    if frames_to_take == -1:
        frame_indexes = range(num_frames)
    else:
        frame_indexes = random.sample(range(num_frames), frames_to_take)
    ans = []
    for f in frame_indexes:
        video.set(cv2.CAP_PROP_POS_FRAMES, f)
        error, image = video.read()
        image_path = f'{video_name}_{left_pad_number(f)}.PNG'
        ans.append({
            'path': image_path,
            'image': image
        })
    return ans

# %%
split_video_into_images(
    'D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/videos/DJI_0804_0001_30m_1.mp4',
    5
)
# Out:
# [{'path': 'DJI_0804_0001_30m_1_000440.PNG',
#   'image': array([[[ 65,  75,  30],
#           [ 65,  75,  30],
#           [ 65,  75,  30],
#           ...,
#           [ 72,  79,  30],
#           [ 72,  79,  30],
#           [ 72,  79,  30]],
#
#          [[ 65,  75,  30],
#           [ 65,  75,  30],
#           [ 65,  75,  30],
#           ...,
#           [ 72,  79,  30],
#           [ 72,  79,  30],
#           [ 72,  79,  30]],
#
#          [[ 65,  75,  30],
#           [ 65,  75,  30],
#           [ 65,  75,  30],
#           ...,
#           [ 72,  79,  30],
#           [ 72,  79,  30],
#           [ 72,  79,  30]],
#
#          ...,
#
#          [[ 66,  79,  32],
#           [ 66,  79,  32],
#           [ 66,  79,  32],
#           ...,
#           [ 85,  86,  49],
#           [ 99, 100,  63],
#           [104, 105,  68]],
#
#          [[ 66,  80,  30],
#           [ 66,  80,  30],
#           [ 66,  80,  30],
#           ...,
#           [ 82,  83,  46],
#           [ 95,  96,  59],
#           [ 99, 100,  63]],
#
#          [[ 64,  78,  28],
#           [ 64,  78,  28],
#           [ 64,  78,  28],
#           ...,
#           [ 70,  71,  34],
#           [ 95,  96,  59],
#           [132, 133,  96]]], dtype=uint8)},
#  {'path': 'DJI_0804_0001_30m_1_000748.PNG',
#   'image': array([[[ 65,  73,  35],
#           [ 65,  73,  35],
#           [ 65,  73,  35],
#           ...,
#           [ 79,  86,  35],
#           [ 80,  87,  36],
#           [ 80,  87,  36]],
#
#          [[ 65,  73,  35],
#           [ 65,  73,  35],
#           [ 65,  73,  35],
#           ...,
#           [ 87,  94,  43],
#           [ 81,  88,  37],
#           [ 73,  80,  29]],
#
#          [[ 65,  73,  35],
#           [ 65,  73,  35],
#           [ 65,  73,  35],
#           ...,
#           [ 81,  88,  37],
#           [ 79,  86,  35],
#           [ 76,  83,  32]],
#
#          ...,
#
#          [[ 61,  75,  32],
#           [ 61,  75,  32],
#           [ 61,  75,  32],
#           ...,
#           [ 80,  79,  39],
#           [ 94,  93,  53],
#           [ 83,  82,  42]],
#
#          [[ 58,  76,  30],
#           [ 58,  76,  30],
#           [ 58,  76,  30],
#           ...,
#           [ 92,  96,  50],
#           [ 78,  82,  36],
#           [ 76,  80,  34]],
#
#          [[ 58,  76,  30],
#           [ 58,  76,  30],
#           [ 58,  76,  30],
#           ...,
#           [119, 123,  77],
#           [ 99, 103,  57],
#           [142, 146, 100]]], dtype=uint8)},
#  {'path': 'DJI_0804_0001_30m_1_000310.PNG',
#   'image': array([[[ 68,  72,  31],
#           [ 68,  72,  31],
#           [ 68,  72,  31],
#           ...,
#           [ 76,  80,  39],
#           [ 76,  80,  39],
#           [ 76,  80,  39]],
#
#          [[ 68,  72,  31],
#           [ 68,  72,  31],
#           [ 68,  72,  31],
#           ...,
#           [ 76,  80,  39],
#           [ 76,  80,  39],
#           [ 76,  80,  39]],
#
#          [[ 68,  72,  31],
#           [ 68,  72,  31],
#           [ 68,  72,  31],
#           ...,
#           [ 76,  80,  39],
#           [ 76,  80,  39],
#           [ 76,  80,  39]],
#
#          ...,
#
#          [[ 94,  99, 117],
#           [ 99, 104, 122],
#           [108, 113, 131],
#           ...,
#           [ 98, 101,  64],
#           [102, 105,  68],
#           [102, 105,  68]],
#
#          [[ 99, 105, 121],
#           [104, 110, 126],
#           [111, 117, 133],
#           ...,
#           [ 96, 101,  64],
#           [100, 105,  68],
#           [101, 106,  69]],
#
#          [[ 98, 104, 120],
#           [100, 106, 122],
#           [107, 113, 129],
#           ...,
#           [ 95, 100,  63],
#           [ 97, 102,  65],
#           [103, 108,  71]]], dtype=uint8)},
#  {'path': 'DJI_0804_0001_30m_1_001046.PNG',
#   'image': array([[[ 58,  62,  28],
#           [ 58,  62,  28],
#           [ 58,  62,  28],
#           ...,
#           [ 74,  90,  63],
#           [ 74,  90,  63],
#           [ 74,  90,  63]],
#
#          [[ 57,  61,  27],
#           [ 57,  61,  27],
#           [ 57,  61,  27],
#           ...,
#           [ 74,  90,  63],
#           [ 74,  90,  63],
#           [ 74,  90,  63]],
#
#          [[ 57,  61,  27],
#           [ 57,  61,  27],
#           [ 57,  61,  27],
#           ...,
#           [ 74,  90,  63],
#           [ 74,  90,  63],
#           [ 74,  90,  63]],
#
#          ...,
#
#          [[ 62,  70,  30],
#           [ 63,  71,  31],
#           [ 63,  71,  31],
#           ...,
#           [ 91, 104,  86],
#           [ 94, 107,  89],
#           [ 93, 106,  88]],
#
#          [[ 63,  71,  31],
#           [ 64,  72,  32],
#           [ 64,  72,  32],
#           ...,
#           [ 89, 106,  88],
#           [ 90, 107,  89],
#           [ 90, 107,  89]],
#
#          [[ 63,  71,  31],
#           [ 64,  72,  32],
#           [ 64,  72,  32],
#           ...,
#           [ 90, 107,  89],
#           [ 90, 107,  89],
#           [ 90, 107,  89]]], dtype=uint8)},
#  {'path': 'DJI_0804_0001_30m_1_001251.PNG',
#   'image': array([[[ 55,  67,  52],
#           [ 55,  67,  52],
#           [ 55,  67,  52],
#           ...,
#           [ 67,  81,  66],
#           [ 67,  81,  66],
#           [ 67,  81,  66]],
#
#          [[ 55,  67,  52],
#           [ 55,  67,  52],
#           [ 55,  67,  52],
#           ...,
#           [ 67,  81,  66],
#           [ 67,  81,  66],
#           [ 67,  81,  66]],
#
#          [[ 55,  67,  52],
#           [ 55,  67,  52],
#           [ 55,  67,  52],
#           ...,
#           [ 67,  81,  66],
#           [ 67,  81,  66],
#           [ 67,  81,  66]],
#
#          ...,
#
#          [[ 53,  69,  54],
#           [ 53,  69,  54],
#           [ 53,  69,  54],
#           ...,
#           [191, 183, 185],
#           [181, 173, 175],
#           [182, 174, 176]],
#
#          [[ 51,  70,  54],
#           [ 51,  70,  54],
#           [ 51,  70,  54],
#           ...,
#           [183, 183, 181],
#           [176, 176, 174],
#           [176, 176, 174]],
#
#          [[ 51,  70,  54],
#           [ 51,  70,  54],
#           [ 51,  70,  54],
#           ...,
#           [179, 179, 177],
#           [173, 173, 171],
#           [164, 164, 162]]], dtype=uint8)}]

# %%
def get_all_files_from_folder(folder_path):
    return [
        os.path.join(folder_path, file).replace('\\', '/')
        for file in os.listdir(folder_path)
        if os.path.isfile(os.path.join(folder_path, file))
    ]

# %% [markdown]
# ## Taking Random frames from each video

# %%
def get_images_for_each_video_from_folder(folder_path, frames_to_take: int=-1):
    return [
        image for video_path in get_all_files_from_folder(folder_path)
        for image in split_video_into_images(video_path, frames_to_take)
    ]

# %%
images = get_images_for_each_video_from_folder('D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/videos', 1)

# %% [markdown]
# ## Splitting into test and training datasets
#
# - [the mobdrone site](https://aimh.isti.cnr.it/dataset/mobdrone/) says that files starting with “DJI_0804” (total: 37,604 images) are testing images and the files starting with “DJI_0915” (total: 88,568 images) are training images
# - training/testing on every single image will not be possible on my laptop, so the dataset will be created by random sampling each video
# - the training/testing will be performed on this random sample, until i can find a way to store and train the complete dataset

# %%
def image_type(image_path):
    image_name = get_file_name_without_extension(image_path)
    if image_name.startswith('DJI_0915'):
        return 'training'
    else:
        return 'testing'

# %%
for image in images:
    print(f"name: {image['path']}, type: {image_type(image['path'])}")
# Out:
# name: DJI_0804_0001_30m_1_000784.PNG, type: testing
# name: DJI_0804_0001_30m_2_000491.PNG, type: testing
# name: DJI_0804_0001_30m_3_000142.PNG, type: testing
# name: DJI_0804_0002_30m_1_000364.PNG, type: testing
# name: DJI_0804_0002_30m_2_001099.PNG, type: testing
# name: DJI_0804_0003_10m_000132.PNG, type: testing
# name: DJI_0804_0004_20m_001358.PNG, type: testing
# name: DJI_0804_0005_30m_000450.PNG, type: testing
# name: DJI_0804_0006_40m_001403.PNG, type: testing
# name: DJI_0804_0007_50m_000171.PNG, type: testing
# name: DJI_0804_0008_20m_001131.PNG, type: testing
# name: DJI_0804_0009_40m_000293.PNG, type: testing
# name: DJI_0804_0010_60m_000678.PNG, type: testing
# name: DJI_0804_0011_30m_1_000498.PNG, type: testing
# name: DJI_0804_0011_30m_2_000169.PNG, type: testing
# name: DJI_0804_0012_50m_1_000415.PNG, type: testing
# name: DJI_0804_0012_50m_2_000011.PNG, type: testing
# name: DJI_0804_0012_50m_3_001390.PNG, type: testing
# name: DJI_0804_0013_40m_000076.PNG, type: testing
# name: DJI_0804_0014_50m_1_000012.PNG, type: testing
# name: DJI_0804_0014_50m_2_000091.PNG, type: testing
# name: DJI_0804_0014_50m_3_000094.PNG, type: testing
# name: DJI_0804_0015_30m_000663.PNG, type: testing
# name: DJI_0804_0016_20m_000322.PNG, type: testing
# name: DJI_0804_0017_40m_000155.PNG, type: testing
# name: DJI_0804_0018_40m_002339.PNG, type: testing
# name: DJI_0915_0001_40m_003181.PNG, type: training
# name: DJI_0915_0002_40m_1_000799.PNG, type: training
# name: DJI_0915_0002_40m_2_001752.PNG, type: training
# name: DJI_0915_0003_50m_001810.PNG, type: training
# name: DJI_0915_0004_50m_003235.PNG, type: training
# name: DJI_0915_0005_60m_003485.PNG, type: training
# name: DJI_0915_0006_60m_1_000182.PNG, type: training
# name: DJI_0915_0006_60m_3_000026.PNG, type: training
# name: DJI_0915_0006_60m_4_000156.PNG, type: training
# name: DJI_0915_0007_40_000568.PNG, type: training
# name: DJI_0915_0008_50m_001111.PNG, type: training
# name: DJI_0915_0009_60m_1_000236.PNG, type: training
# name: DJI_0915_0009_60m_3_001036.PNG, type: training
# name: DJI_0915_0009_60m_5_000051.PNG, type: training
# name: DJI_0915_0010_60m_000152.PNG, type: training
# name: DJI_0915_0011_30m_003477.PNG, type: training
# name: DJI_0915_0012_30m_001298.PNG, type: training
# name: DJI_0915_0013_40m_002479.PNG, type: training
# name: DJI_0915_0014_40m_003380.PNG, type: training
# name: DJI_0915_0015_50m_004612.PNG, type: training
# name: DJI_0915_0016_50m_1_000385.PNG, type: training
# name: DJI_0915_0016_50m_2_000270.PNG, type: training
# name: DJI_0915_0016_50m_3_000215.PNG, type: training
# name: DJI_0915_0017_60m_000577.PNG, type: training
# name: DJI_0915_0018_60m_002932.PNG, type: training
# name: DJI_0915_0019_60m_000878.PNG, type: training
# name: DJI_0915_0020_30m_000045.PNG, type: training
# name: DJI_0915_0021_30m_000206.PNG, type: training
# name: DJI_0915_0022_40m_002817.PNG, type: training
# name: DJI_0915_0023_50m_002168.PNG, type: training
# name: DJI_0915_0024_60m_1_000985.PNG, type: training
# name: DJI_0915_0024_60m_2_000432.PNG, type: training
# name: DJI_0915_0025_30m_002027.PNG, type: training
# name: DJI_0915_0026_40m_000796.PNG, type: training
# name: DJI_0915_0027_50m_001314.PNG, type: training
# name: DJI_0915_0028_60m_001632.PNG, type: training
# name: DJI_0915_0029_30m_001685.PNG, type: training
# name: DJI_0915_0030_20m_1_001127.PNG, type: training
# name: DJI_0915_0030_20m_2_000078.PNG, type: training
# name: DJI_0915_0031_20m_000170.PNG, type: training

# %% [markdown]
# ## Getting the annotations for the images taken

# %%
def get_coco_annotations(images, only_annotated_images: bool=False):
    complete_annotations_file = 'D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/annotations/5-class-annotations.json'

    annotation_data = None
    with open(complete_annotations_file, 'r') as file:
        annotation_data = json.load(file)


    # print(annotation_data['annotations'][0])
    # print(annotation_data['images'][0])

    annotations = {}
    annotations['categories'] = annotation_data['categories']
    annotations['images'] = []
    annotations['annotations'] = []
    # print(annotations)

    image_paths = set([image['path'] for image in images])
    # print(image_paths)

    image_ids = set()
    num_anns = {}
    for image in annotation_data['images']:
        if image['file_name'] in image_paths:
            image_ids.add(image['id'])
            num_anns[image['id']] = 0
            annotations['images'].append(image)

    for an in annotation_data['annotations']:
        if an['image_id'] in image_ids:
            annotations['annotations'].append(an)
            num_anns[an['image_id']] += 1
    # print(num_anns)

    if only_annotated_images:
        annotated_images = []
        for image in annotations['images']:
            if num_anns[image['id']] > 0:
                annotated_images.append(image)
        annotations['images'] = annotated_images
    return annotations

# %%
get_coco_annotations(images, True)
# Out:
# {785: 0, 1751: 0, 2189: 1, 2693: 0, 5040: 0, 5652: 0, 7836: 0, 8376: 0, 10733: 1, 10960: 1, 13370: 0, 14008: 4, 16273: 3, 17761: 3, 19251: 2, 20558: 0, 22250: 3, 23687: 3, 24178: 7, 25014: 5, 26590: 14, 27833: 14, 28925: 4, 31962: 3, 33810: 2, 37583: 5, 40786: 0, 41709: 0, 43487: 1, 45635: 1, 49695: 1, 53572: 0, 53793: 1, 54270: 1, 54867: 0, 61543: 2, 63661: 1, 64806: 1, 65102: 0, 71167: 1, 76053: 1, 79440: 0, 83987: 3, 89719: 2, 90822: 1, 91753: 2, 92020: 1, 93523: 1, 97364: 2, 98689: 1, 99708: 0, 100837: 2, 105023: 1, 107336: 1, 108354: 1, 108924: 1, 111261: 1, 112548: 1, 115189: 0, 117526: 2, 119371: 1, 120704: 1, 121215: 1, 121861: 1, 124927: 0}
# {'categories': [{'id': 1, 'name': 'person', 'supercategory': ''},
#   {'id': 2, 'name': 'boat', 'supercategory': ''},
#   {'id': 3, 'name': 'surfboard', 'supercategory': ''},
#   {'id': 4, 'name': 'wood', 'supercategory': ''},
#   {'id': 5, 'name': 'life_buoy', 'supercategory': ''}],
#  'images': [{'id': 2189,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0001_30m_3_000142.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 10733,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0006_40m_001403.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 10960,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0007_50m_000171.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 14008,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0009_40m_000293.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 16273,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0010_60m_000678.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 17761,
#    'width': 1920,
#    'height': 1012,
#    'file_name': 'DJI_0804_0011_30m_1_000498.PNG',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id':

#    'category_id': 1,
#    'segmentation': [],
#    'area': 2759.711999999999,
#    'bbox': [552.42, 283.39, 38.76, 71.2],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 22949,
#    'image_id': 17761,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 4456.264099999998,
#    'bbox': [1005.47, 214.13, 60.77, 73.33],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 22950,
#    'image_id': 17761,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 1195.0849000000014,
#    'bbox': [259.91, 702.16, 34.57, 34.57],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 5, 'keyframe': False}},
#   {'id': 24683,
#    'image_id': 19251,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2907.7390000000064,
#    'bbox': [1413.35, 235.99, 66.1, 43.99],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 24684,
#    'image_id': 19251,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 1377.301800000003,
#    'bbox': [882.5, 529.76, 38.71, 35.58],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 5, 'keyframe': False}},
#   {'id': 29538,
#    'image_id': 22250,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 354.5971,
#    'bbox': [326.21, 4.17, 17.81, 19.91],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': True}},
#   {'id': 29539,
#    'image_id': 22250,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 631.3900000000001,
#    'bbox': [398.66, 60.63, 25.75, 24.52],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': True}},
#   {'id': 29540,
#    'image_id': 22250,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 842.2754000000009,
#    'bbox': [310.03, 38.07, 26.47, 31.82],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 2, 'keyframe': False}},
#   {'id': 36240,
#    'image_id': 23687,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1115.9450000000004,
#    'bbox': [996.93, 237.25, 36.35, 30.7],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 36241,
#    'image_id': 23687,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 599.9503999999988,
#    'bbox': [1037.67, 398.31, 23.29, 25.76],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 11, 'keyframe': False}},
#   {'id': 36242,
#    'image_id': 23687,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 502.8692000000034,
#    'bbox': [1452.62, 450.9, 20.84, 24.13],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 12, 'keyframe': False}},
#   {'id': 37949,
#    'image_id': 24178,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 631.1447999999998,
#    'bbox': [494.12, 426.93, 25.74, 24.52],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': True}},
#   {'id': 37950,
#    'image_id': 24178,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 384.74820000000034,
#    'bbox': [465.08, 350.98, 19.61, 19.62],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 5, 'keyframe': False}},
#   {'id': 37951,
#    'image_id': 24178,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 255.32219999999967,
#    'bbox': [617.95, 23.56, 13.02, 19.61],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 6, 'keyframe': False}},
#   {'id': 37952,
#    'image_id': 24178,
#    'category_id': 3,
#    'segmentation': [],
#    'area': 663.5456000000005,
#    'bbox': [609.36, 38.27, 31.84, 20.84],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 7, 'keyframe': True}},
#   {'id': 37953,
#    'image_id': 24178,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 2380.9116,
#    'bbox': [508.83, 40.72, 53.94, 44.14],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 8, 'keyframe': True}},
#   {'id': 37954,
#    'image_id': 24178,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 293.1366,
#    'bbox': [110.36, 412.21, 18.39, 15.94],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 9, 'keyframe': True}},
#   {'id': 37955,
#    'image_id': 24178,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 7049.9987999999985,
#    'bbox': [36.8, 159.65, 139.77, 50.44],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 43871,
#    'image_id': 25014,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 22695.852599999995,
#    'bbox': [37.64, 833.49, 139.77, 162.38],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 12, 'keyframe': False}},
#   {'id': 43872,
#    'image_id': 25014,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 459.9388000000017,
#    'bbox': [729.15, 845.01, 20.84, 22.07],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 13, 'keyframe': False}},
#   {'id': 43873,
#    'image_id': 25014,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 6899.008500000002,
#    'bbox': [80.55, 494.07, 125.05, 55.17],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 14, 'keyframe': False}},
#   {'id': 43874,
#    'image_id': 25014,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 793.4573999999997,
#    'bbox': [917.88, 660.04, 29.42, 26.97],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 15, 'keyframe': False}},
#   {'id': 43875,
#    'image_id': 25014,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 977.1220000000028,
#    'bbox': [1112.77, 677.87, 30.65, 31.88],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 16, 'keyframe': False}},
#   {'id': 50683,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 402.2119999999975,
#    'bbox': [775.19, 845.76, 20.84, 19.3],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 50684,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 637.8264999999978,
#    'bbox': [899.63, 786.7, 30.65, 20.81],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 6, 'keyframe': False}},
#   {'id': 50685,
#    'image_id': 26590,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 1681.465500000003,
#    'bbox': [478.71, 442.33, 45.63, 36.85],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 7, 'keyframe': False}},
#   {'id': 50686,
#    'image_id': 26590,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 6762.3707999999915,
#    'bbox': [1463.69, 482.63, 73.56, 91.93],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 8, 'keyframe': False}},
#   {'id': 50687,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 371.402000000001,
#    'bbox': [952.66, 203.8, 15.94, 23.3],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 9, 'keyframe': False}},
#   {'id': 50688,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 351.79579999999856,
#    'bbox': [733.35, 304.55, 15.94, 22.07],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 50689,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 235.09800000000024,
#    'bbox': [971.0, 198.61, 11.1, 21.18],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 11, 'keyframe': False}},
#   {'id': 50690,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 427.5760000000018,
#    'bbox': [983.3, 195.17, 18.43, 23.2],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 12, 'keyframe': False}},
#   {'id': 50691,
#    'image_id': 26590,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 1869.6599999999976,
#    'bbox': [814.19, 251.66, 84.6, 22.1],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 13, 'keyframe': False}},
#   {'id': 50692,
#    'image_id': 26590,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 2515.5999999999995,
#    'bbox': [1047.07, 256.74, 38.0, 66.2],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 14, 'keyframe': False}},
#   {'id': 50693,
#    'image_id': 26590,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 3127.428000000004,
#    'bbox': [1086.3, 214.82, 98.1, 31.88],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 15, 'keyframe': False}},
#   {'id': 50694,
#    'image_id': 26590,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 4219.121500000006,
#    'bbox': [1195.5, 218.8, 95.65, 44.11],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 16, 'keyframe': False}},
#   {'id': 50695,
#    'image_id': 26590,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 431.1999999999999,
#    'bbox': [696.27, 219.55, 22.0, 19.6],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 17, 'keyframe': False}},
#   {'id': 50696,
#    'image_id': 26590,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 360.24800000000255,
#    'bbox': [1069.3, 570.4, 18.38, 19.6],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 18, 'keyframe': False}},
#   {'id': 67885,
#    'image_id': 27833,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 274.3273999999997,
#    'bbox': [1005.93, 891.71, 15.94, 17.21],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 11, 'keyframe': False}},
#   {'id': 67886,
#    'image_id': 27833,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 8475.583199999988,
#    'bbox': [1535.21, 772.09, 73.56, 115.22],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 12, 'keyframe': False}},
#   {'id': 67887,
#    'image_id': 27833,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 2002.6317999999997,
#    'bbox': [280.78, 663.99, 45.37, 44.14],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 13, 'keyframe': False}},
#   {'id': 67888,
#    'image_id': 27833,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 352.4334000000005,
#    'bbox': [592.02, 347.29, 15.94, 22.11],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 14, 'keyframe': False}},
#   {'id': 67889,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 3249.592200000004,
#    'bbox': [713.05, 413.76, 94.41, 34.42],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 15, 'keyframe': False}},
#   {'id': 67890,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 2164.380400000003,
#    'bbox': [752.29, 387.08, 88.27, 24.52],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 16, 'keyframe': False}},
#   {'id': 67891,
#    'image_id': 27833,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 483.67890000000233,
#    'bbox': [910.79, 330.53, 17.17, 28.17],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 17, 'keyframe': False}},
#   {'id': 67892,
#    'image_id': 27833,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 471.59500000000037,
#    'bbox': [932.36, 318.31, 18.35, 25.7],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 18, 'keyframe': False}},
#   {'id': 67893,
#    'image_id': 27833,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 356.58479999999986,
#    'bbox': [947.9, 332.08, 17.16, 20.78],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 19, 'keyframe': False}},
#   {'id': 67894,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 1947.9349999999954,
#    'bbox': [1021.98, 405.28, 33.1, 58.85],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 20, 'keyframe': False}},
#   {'id': 67895,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 4271.3324999999895,
#    'bbox': [1068.96, 343.47, 120.15, 35.55],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 21, 'keyframe': False}},
#   {'id': 67896,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 3478.745599999996,
#    'bbox': [1080.92, 421.22, 109.12, 31.88],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 22, 'keyframe': False}},
#   {'id': 67897,
#    'image_id': 27833,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 421.1800999999957,
#    'bbox': [1142.17, 445.05, 17.17, 24.53],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 23, 'keyframe': False}},
#   {'id': 67898,
#    'image_id': 27833,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 5739.263999999997,
#    'bbox': [1199.27, 353.8, 101.76, 56.4],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 24, 'keyframe': False}},
#   {'id': 75297,
#    'image_id': 28925,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 15620.764800000015,
#    'bbox': [1678.85, 734.7, 153.28, 101.91],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 75298,
#    'image_id': 28925,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 410.25419999999946,
#    'bbox': [551.33, 567.44, 19.62, 20.91],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 16, 'keyframe': False}},
#   {'id': 75299,
#    'image_id': 28925,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 382.7910999999998,
#    'bbox': [658.03, 265.67, 20.77, 18.43],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 17, 'keyframe': False}},
#   {'id': 75300,
#    'image_id': 28925,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 557.3619999999987,
#    'bbox': [818.59, 228.26, 25.22, 22.1],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 18, 'keyframe': False}},
#   {'id': 80540,
#    'image_id': 31962,
#    'category_id': 5,
#    'segmentation': [],
#    'area': 472.25499999999687,
#    'bbox': [493.55, 610.08, 25.75, 18.34],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 9, 'keyframe': False}},
#   {'id': 80541,
#    'image_id': 31962,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 536.2132000000012,
#    'bbox': [820.63, 170.54, 20.84, 25.73],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 80542,
#    'image_id': 31962,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 294.4655999999999,
#    'bbox': [1011.32, 159.7, 17.16, 17.16],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 11, 'keyframe': False}},
#   {'id': 84358,
#    'image_id': 33810,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 666.8424,
#    'bbox': [615.08, 437.05, 27.51, 24.24],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 84359,
#    'image_id': 33810,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1035.5669000000003,
#    'bbox': [732.45, 385.54, 35.87, 28.87],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 11, 'keyframe': False}},
#   {'id': 89503,
#    'image_id': 37583,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1014.4153999999966,
#    'bbox': [1233.44, 880.37, 33.14, 30.61],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 5, 'keyframe': False}},
#   {'id': 89504,
#    'image_id': 37583,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1060.6614000000031,
#    'bbox': [1065.8, 896.88, 31.89, 33.26],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 6, 'keyframe': False}},
#   {'id': 89505,
#    'image_id': 37583,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 12475.197000000006,
#    'bbox': [45.38, 859.04, 89.46, 139.45],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 7, 'keyframe': False}},
#   {'id': 89506,
#    'image_id': 37583,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 30306.658699999945,
#    'bbox': [1501.89, 144.18, 116.47, 260.21],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 9, 'keyframe': False}},
#   {'id': 89507,
#    'image_id': 37583,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 21079.129600000015,
#    'bbox': [911.79, 8.99, 225.59, 93.44],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 95663,
#    'image_id': 43487,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 3232.9086000000084,
#    'bbox': [901.88, 842.31, 65.47, 49.38],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 3, 'keyframe': False}},
#   {'id': 97611,
#    'image_id': 45635,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 936.8292999999999,
#    'bbox': [940.4, 919.62, 25.73, 36.41],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 3, 'keyframe': False}},
#   {'id': 102765,
#    'image_id': 49695,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2116.463800000004,
#    'bbox': [1391.35, 472.28, 50.38, 42.01],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 6, 'keyframe': False}},
#   {'id': 106202,
#    'image_id': 53793,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1541.5530000000012,
#    'bbox': [808.48, 908.3, 40.89, 37.7],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 106758,
#    'image_id': 54270,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 21168.290300000008,
#    'bbox': [595.26, 133.28, 182.69, 115.87],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 114180,
#    'image_id': 61543,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1784.285999999998,
#    'bbox': [1312.27, 365.71, 44.1, 40.46],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 114181,
#    'image_id': 61543,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1575.5087999999992,
#    'bbox': [32.54, 552.32, 51.42, 30.64],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 115424,
#    'image_id': 63661,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1416.3600000000006,
#    'bbox': [1349.65, 427.64, 33.0, 42.92],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 116867,
#    'image_id': 64806,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1073.2599999999986,
#    'bbox': [329.85, 455.63, 41.68, 25.75],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 121747,
#    'image_id': 71167,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 3465.336200000005,
#    'bbox': [1474.61, 516.99, 76.43, 45.34],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 124999,
#    'image_id': 76053,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 5332.413700000005,
#    'bbox': [541.01, 892.17, 69.97, 76.21],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 133188,
#    'image_id': 83987,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 42667.99000000002,
#    'bbox': [1682.61, 618.56, 166.75, 255.88],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 6, 'keyframe': False}},
#   {'id': 133189,
#    'image_id': 83987,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 864.3300000000007,
#    'bbox': [1345.12, 342.91, 28.2, 30.65],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 7, 'keyframe': False}},
#   {'id': 133190,
#    'image_id': 83987,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 3511.2236999999973,
#    'bbox': [1170.98, 253.79, 61.31, 57.27],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 8, 'keyframe': False}},
#   {'id': 141449,
#    'image_id': 89719,
#    'category_id': 4,
#    'segmentation': [],
#    'area': 896.0679000000025,
#    'bbox': [298.03, 921.06, 24.57, 36.47],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 9, 'keyframe': False}},
#   {'id': 141450,
#    'image_id': 89719,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1323.0349999999999,
#    'bbox': [1062.33, 587.78, 25.75, 51.38],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 10, 'keyframe': False}},
#   {'id': 142192,
#    'image_id': 90822,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1797.600000000003,
#    'bbox': [602.48, 489.44, 32.1, 56.0],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 143789,
#    'image_id': 91753,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2316.2194000000036,
#    'bbox': [512.54, 405.05, 36.43, 63.58],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 143790,
#    'image_id': 91753,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 782.5719999999966,
#    'bbox': [1868.94, 976.41, 29.42, 26.6],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 144072,
#    'image_id': 92020,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1733.256000000003,
#    'bbox': [410.78, 929.53, 27.15, 63.84],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 145008,
#    'image_id': 93523,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1390.0222000000008,
#    'bbox': [147.55, 433.94, 48.91, 28.42],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 150078,
#    'image_id': 97364,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 15585.6476,
#    'bbox': [1527.3, 933.98, 208.42, 74.78],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 3, 'keyframe': False}},
#   {'id': 150079,
#    'image_id': 97364,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 697.5583999999992,
#    'bbox': [826.15, 482.6, 20.86, 33.44],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 5, 'keyframe': False}},
#   {'id': 153636,
#    'image_id': 98689,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1536.3359999999998,
#    'bbox': [783.32, 552.39, 56.4, 27.24],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 155775,
#    'image_id': 100837,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2471.8400000000056,
#    'bbox': [1210.05, 150.72, 44.14, 56.0],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 155776,
#    'image_id': 100837,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 75518.62940000002,
#    'bbox': [418.38, 800.3, 358.01, 210.94],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 2, 'keyframe': False}},
#   {'id': 160212,
#    'image_id': 105023,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 30149.30160000001,
#    'bbox': [895.6, 719.42, 281.98, 106.92],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 3, 'keyframe': False}},
#   {'id': 162766,
#    'image_id': 107336,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 22352.19119999998,
#    'bbox': [1118.68, 381.85, 221.88, 100.74],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 3, 'keyframe': False}},
#   {'id': 164295,
#    'image_id': 108354,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1713.1545000000053,
#    'bbox': [810.78, 712.27, 48.19, 35.55],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 165022,
#    'image_id': 108924,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1357.3560000000011,
#    'bbox': [1331.81, 450.06, 46.2, 29.38],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 2, 'keyframe': False}},
#   {'id': 167394,
#    'image_id': 111261,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 5923.669500000005,
#    'bbox': [1268.51, 109.78, 80.43, 73.65],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 168790,
#    'image_id': 112548,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2911.7499999999977,
#    'bbox': [815.19, 591.72, 61.3, 47.5],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}},
#   {'id': 175105,
#    'image_id': 117526,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 17218.015199999987,
#    'bbox': [840.84, 810.76, 174.06, 98.92],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 2, 'keyframe': False}},
#   {'id': 175106,
#    'image_id': 117526,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 1663.546000000004,
#    'bbox': [948.15, 266.58, 38.05, 43.72],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 177066,
#    'image_id': 119371,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 35109.40680000001,
#    'bbox': [936.72, 876.28, 258.69, 135.72],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 4, 'keyframe': False}},
#   {'id': 177807,
#    'image_id': 120704,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2288.6196000000014,
#    'bbox': [1100.04, 502.14, 49.26, 46.46],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 1, 'keyframe': False}},
#   {'id': 178227,
#    'image_id': 121215,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 2873.772,
#    'bbox': [865.49, 388.9, 44.28, 64.9],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': True}},
#   {'id': 178594,
#    'image_id': 121861,
#    'category_id': 1,
#    'segmentation': [],
#    'area': 6209.130199999988,
#    'bbox': [1297.85, 945.94, 128.74, 48.23],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'track_id': 0, 'keyframe': False}}]}

# %% [markdown]
# ## Consolidating Everything

# %%
def create_dataset(source_folder: str, destination_folder: str, images_per_video: int=-1, only_annotated_image_in_annotations_file: bool=False):
    images = get_images_for_each_video_from_folder('D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/videos', images_per_video)
    annotations = get_coco_annotations(images, only_annotated_image_in_annotations_file)

    training_folder_name = os.path.join(destination_folder, 'training')
    testing_folder_name = os.path.join(destination_folder, 'testing')

    if not os.path.isdir(training_folder_name):
        os.mkdir(training_folder_name)
    if not os.path.isdir(testing_folder_name):
        os.mkdir(testing_folder_name)

    for image in images:
        cv2.imwrite(f"{destination_folder}/{image_type(image['path'])}/{image['path']}", image['image'])
    
    with open(f'{destination_folder}/annotations.json', 'w') as file:
        json.dump(annotations, file)

# %% [markdown]
# ## Creating the Datasets

# %%
# create_dataset(
#     'D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/videos',
#     'D:/VIT/year4/sem8/Capstone/datasets/MOBDrone/single_image_set',
#     1,
#     only_annotated_image_in_annotations_file=True
# )
# Out:
# {275: 4, 1499: 8, 2080: 0, 3693: 0, 4469: 3, 6044: 0, 7820: 0, 8592: 0, 10245: 0, 11584: 2, 13516: 2, 15256: 2, 15808: 4, 17746: 3, 19642: 0, 21049: 1, 22289: 3, 23832: 3, 24394: 6, 26406: 1, 27072: 13, 27803: 14, 31013: 0, 31710: 3, 34246: 0, 36465: 0, 38670: 0, 41056: 0, 43140: 2, 45110: 0, 46537: 1, 51033: 1, 54138: 1, 54689: 4, 54754: 1, 61319: 2, 63703: 1, 64780: 1, 66331: 1, 70526: 0, 76840: 1, 79709: 2, 83263: 1, 89670: 2, 91153: 0, 91487: 4, 92185: 1, 93516: 1, 95395: 1, 98952: 1, 99866: 1, 101779: 1, 102964: 2, 106268: 1, 108476: 1, 108800: 2, 110498: 1, 112895: 1, 114035: 1, 116852: 0, 118466: 1, 119831: 0, 121503: 1, 123256: 0, 125903: 2}

